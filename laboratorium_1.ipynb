# %% [markdown]
# Piotr Żak

# %% [markdown]
# Zadanie 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

f = lambda x: x**2 +5
x1 = np.linspace(-1, 1, 100)
x2 = np.linspace(-6, 6, 100)
x3 = np.linspace(0, 5, 100)

y1 = f(x1)
y2 = f(x2)
y3 = f(x3)

plt.plot(x1, y1)
plt.title('przedział 1')
plt.legend()
plt.xlabel('x1')
plt.ylabel('f(x1)')
plt.show()

# %%
plt.plot(x2, y2)
plt.title('przedział 2')
plt.legend()
plt.xlabel('x2')
plt.ylabel('f(x2)')
plt.show()

# %%
plt.plot(x3, y3)
plt.title('przedział 3')
plt.legend()
plt.xlabel('x3')
plt.ylabel('f(x3)')
plt.show()

# %% [markdown]
# Zadanie 4

# %%
data = {'name': ['Adam', 'Barbara', 'Cezary', 'Dominika', 'Ewelina'], 'surname': ['Kowalski', 'Nowak', 'Wójcik', 'Dudek', 'Bąk'], 'age': [25, 17, 35, 87, 20], 'sex': ['M', 'K', 'M', 'K', 'K']}
df = pd.DataFrame(data = data)
print(df)
# Out:
#        name   surname  age sex
# 0      Adam  Kowalski   25   M
# 1   Barbara     Nowak   17   K
# 2    Cezary    Wójcik   35   M
# 3  Dominika     Dudek   87   K
# 4   Ewelina       Bąk   20   K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 164.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   36.800000
# std    28.882521
# min    17.000000
# 25%    20.000000
# 50%    25.000000
# 75%    35.000000
# max    87.000000

# %%
df.head(n=3)
# Out:
#       name   surname  age sex
# 0     Adam  Kowalski   25   M
# 1  Barbara     Nowak   17   K
# 2   Cezary    Wójcik   35   M
